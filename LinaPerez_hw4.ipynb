# %%
# %pylab inlineimport osimport numpy as np
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type 'help(pylab)'.

# %% [markdown]
# Salida de Campo al planeta Brahe-3141-f! - Procesamiento de Datos

# %%
#crea una lista con los 1000 archivos tomados en campolista = os.listdir("Brahe-3141-f")#el tamao de la listasize = size(lista)

# %% [markdown]
# Dentro de los 1000 datos tomados en campo, se encontraron algunos archivos con ruido, los cuales daan el trabajo realizado para medir la gravedad.siendo asi se va a detectar estos archivos y separar los buenos de los ruidosos

# %%
print lista
# Out:
# ['experiment_theta_139.2_phi_357.2.dat', 'experiment_theta_70.5_phi_73.0.dat', 'experiment_theta_29.2_phi_331.9.dat', 'experiment_theta_111.9_phi_135.2.dat', 'experiment_theta_73.9_phi_267.9.dat', 'experiment_theta_26.4_phi_226.6.dat', 'experiment_theta_103.9_phi_219.8.dat', 'experiment_theta_62.6_phi_267.9.dat', 'experiment_theta_51.9_phi_159.4.dat', 'experiment_theta_56.3_phi_4.6.dat', 'experiment_theta_37.1_phi_105.0.dat', 'experiment_theta_118.7_phi_107.1.dat', 'experiment_theta_111.0_phi_122.0.dat', 'experiment_theta_74.9_phi_213.7.dat', 'experiment_theta_155.5_phi_272.4.dat', 'experiment_theta_28.4_phi_255.8.dat', 'experiment_theta_32.1_phi_46.5.dat', 'experiment_theta_109.0_phi_302.7.dat', 'experiment_theta_30.7_phi_288.4.dat', 'experiment_theta_105.2_phi_285.1.dat', 'experiment_theta_22.7_phi_269.7.dat', 'experiment_theta_48.3_phi_203.1.dat', 'experiment_theta_44.3_phi_357.7.dat', 'experiment_theta_106.4_phi_209.9.dat', 'experiment_theta_60.6_phi_305.8.dat', 'experiment_theta
# ...

# %% [markdown]
# Ahora vamos a graficas todos los datos para asegurarnos como es la distribucion de estos y como es la relacion de los buenos contra los que son de ruido

# %%
for i in range(size):    archivo = loadtxt("Brahe-3141-f/"+lista[i])    zip(*archivo)    c1, c2=zip(*archivo)    plot(c1,c2)

# %% [markdown]
# Ahora vamos a separar los archivos buenos de los archivos con ruido

# %%
for i in range(size):    archivo = loadtxt("Brahe-3141-f/"+lista[i])

# %%
A=[]B=[]for i in range(38):    A=np.append(A,archivo[i][0])    B=np.append(B,archivo[i][1])

# %%
A,B
# Out:
# (array([ 0.      ,  0.108108,  0.216216,  0.324324,  0.432432,  0.540541,        0.648649,  0.756757,  0.864865,  0.972973,  1.081081,  1.189189,        1.297297,  1.405405,  1.513514,  1.621622,  1.72973 ,  1.837838,        1.945946,  2.054054,  2.162162,  2.27027 ,  2.378378,  2.486486,        2.594595,  2.702703,  2.810811,  2.918919,  3.027027,  3.135135,        3.243243,  3.351351,  3.459459,  3.567568,  3.675676,  3.783784,        3.891892,  4.      ]), array([  1.164438,   3.291154,   5.309199,   7.218573,   9.019275,        10.711305,  12.294665,  13.769353,  15.135369,  16.392714,        17.541388,  18.581391,  19.512722,  20.335381,  21.049369,        21.654686,  22.151332,  22.539306,  22.818608,  22.98924 ,        23.0512  ,  23.004488,  22.849105,  22.585051,  22.212325,        21.730928,  21.14086 ,  20.44212 ,  19.634709,  18.718626,        17.693872,  16.560447,  15.31835 ,  13.967582,  12.508142,        10.940031,   9.263249,   7.477795]))

# %%
archivo
# Out:
# array([[  0.      ,   1.164438],       [  0.108108,   3.291154],       [  0.216216,   5.309199],       [  0.324324,   7.218573],       [  0.432432,   9.019275],       [  0.540541,  10.711305],       [  0.648649,  12.294665],       [  0.756757,  13.769353],       [  0.864865,  15.135369],       [  0.972973,  16.392714],       [  1.081081,  17.541388],       [  1.189189,  18.581391],       [  1.297297,  19.512722],       [  1.405405,  20.335381],       [  1.513514,  21.049369],       [  1.621622,  21.654686],       [  1.72973 ,  22.151332],       [  1.837838,  22.539306],       [  1.945946,  22.818608],       [  2.054054,  22.98924 ],       [  2.162162,  23.0512  ],       [  2.27027 ,  23.004488],       [  2.378378,  22.849105],       [  2.486486,  22.585051],       [  2.594595,  22.212325],       [  2.702703,  21.730928],       [  2.810811,  21.14086 ],       [  2.918919,  20.44212 ],       [  3.027027,  19.634709],       [  3.135135,  18.718626],       [  3.243243,  17.693872],      
# ...
